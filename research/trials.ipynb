# %%
d={"key":"value"}

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
import gdown

# %%
def get_prodict(x:int,y:int)-> int:
    return x*y

# %%
get_prodict(x=2,y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int,y:int)-> int:
    return x*y

# %%
get_prodict(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_prodict(x=2,y="3")
#
# File c:\Users\gk414\anaconda3\envs\kidney_tf\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x000001DDA7F26EE0> does not match annotation type <class 'int'>

# %%
#download data
import gdown

# %%
url="https://drive.google.com/file/d/1l-OBE2ht1O5nBuwbEhEthlfbOF6-WkVZ/view?usp=sharing"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1l-OBE2ht1O5nBuwbEhEthlfbOF6-WkVZ'

# %%
prefix="https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id,"kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1l-OBE2ht1O5nBuwbEhEthlfbOF6-WkVZ
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1l-OBE2ht1O5nBuwbEhEthlfbOF6-WkVZ&confirm=t&uuid=36fe1e90-6020-43f6-9fd1-c855f41ae613
# To: c:\Users\gk414\PycharmProjects\Kidney-Disease-Classification-Deep-Learning-Project\research\kidney-CT-Scan-data.zip
# 100%|██████████| 47.2M/47.2M [00:07<00:00, 6.49MB/s]
# 'kidney-CT-Scan-data.zip'
